# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 2*np.pi, 128)

# %%
f = np.sin(t)

# %%
plt.plot(t,f)
plt.grid()

# %%
plt.scatter(t,f, s= 2)
plt.grid()

# %%
y = np.fft.fft(f)

# %%
# Out:
# (0.0, 1.0)
